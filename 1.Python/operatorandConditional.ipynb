# %% [markdown]
# Operator are symbols represented to perform any operation

# %%
a=10
b=20

# Arithmetic Operator  
print("Addition",a+b)
print("Subtraction",a-b)
print("Multiplication",a*b)
print("Division",a/b)
print("Modulus",a%b)
print("Exponent",a**b)
print("Floor Division",a//b
# Out:
# Addition 30
# Subtraction -10
# Multiplication 200
# Division 0.5
# Modulus 10
# Exponent 100000000000000000000
# Floor Division 0

# %%
# Assignment Opearator 
a=10
a += 5
print(a)
a -= 5
print(a)
a *= 5
print(a)
a /= 5
print(a)
a %= 5
print(a)
a **= 5
print(a)
a //= 5
print(a)
# Out:
# 15
# 10
# 50
# 10.0
# 0.0
# 0.0
# 0.0

# %%
# Comparison Operator
a=10
b=20

print("a is Equal to b",a==b)
print("a is Not equal to b",a!=b)
print("a is Greater than b",a>b)
print("a is Less than b",a<b)
print("a is Greater than or equal to b",a>=b)
print("a is Less than or equal to b",a<=b)
# Out:
# a is Equal to b False
# a is Not equal to b True
# a is Greater than b False
# a is Less than b True
# a is Greater than or equal to b False
# a is Less than or equal to b True

# %%
# Logical Operator  
a=True
b=False
print("AND ",a and b)
print("OR ",a or b)
print("NOT ",not a)

age=15
is_student=True

print("Can driving licence",age>=18 and is_student)
# Out:
# AND  False
# OR  True
# NOT  False
# Can driving licence False

# %%
# Membership operator 
# check value exist inside a sequence 

fruits= ["apple","orange","banana"]
print("apple" in fruits)
print("grapes" not in fruits)
# Out:
# True
# True

# %%
# Identify Operator 
# Check whether two variables refer to the sameo object in memory or not 

a=[1,2,3]
b=a
c=[1,2,3]

print("a is b",a is b)
print("a is c",a is c)
print("a is not c",a is not c)
#check values 
print("a == c",a == c)
# Out:
# a is b True
# a is c False
# a is not c True
# a == c True

# %%
# Operator predence 
# FIRST BRACKET, THEN DMAS
result = (2 + 3) * 4
print(result)
# Out:
# 20

# %%
# Conditional Statements    

age=18
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
number=0
if number>0:
    print("Positive is Integer")
elif number==0:
    print("Zero is Integer")
else:
    print("Negative is Integer")
# Out:
# Zero is Integer

# %%
number =10
if number >=0:
    if number ==0:
        print("Zero Number")
    else:
        print("Positive Number")
else:
    print("Negative Number")
# Out:
# Positive Number

# %%
# for loop
languages = ["python","jaavscript","c++"]

for langauge in languages:
    print(langauge)
# Out:
# python
# jaavscript
# c++

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(type(range(5)))
# Out:
# <class 'range'>

# %%
# while loop
count=0
n=10
sum=0
while (count<=n):
    sum += count
    count += 1


print("Sum of {} is {}" .format(n,sum))
# Out:
# Sum of 10 is 55

# %%
while True:
    print("Hello")
    break
# Out:
# Hello

# %%
# Check whether it is prime number or not 

num = int(input("Enter the number : "))
while num %2 ==0:
    print("Not a prime number")
    break
else:
    print("It is a prime number")
# Out:
# Not a prime number

# %%
#check wheteher year is leap year or not
num = int(input("Enter the number : "))

if(num %4==0):
    if(num %100==0):
        if(num%400==0):
            print("It is a leap year")
        else:
            print("It is not a leap year")
    else:
        print("It is a leap year")
else:
    print("It is not a leap year")
# Out:
# It is not a leap year

# %%
# break => break the loop
# continue => skip the current iteration
# pass => do nothing

for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(5):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
# switch statament 
language = "java"

match language:
    case "javascript":
        print("Javascript")
    case "python":
        print("Python")
    case "java":
        print("Java")
    case _:
        print("Default")
# Out:
# Java

# %%
# Function => Function is a block of code that perform certain tasks 

# Standard Library function 
# User Defined Function 


def greet():
    print("Hello")
    
greet() 
def sum_number(num1,num2):
    sum = num1 + num2
    return sum

print(sum_number(1,2))


def square_num(num):
    return num * num

print(square_num(5))    

print(pow(2,4))

# Benefits of fubnction is code reuable and readability
# Out:
# Hello
# 3
# 25
# 16

# %%
langauges = ["java","javascript","python"]

langauges.append("golang")

print(langauges)
print(langauges[1])
print(langauges[2:])
print(langauges[-1])
print(langauges[-2])
print(langauges[::-1])
print(langauges[::-2])


del langauges[0]
print(langauges)
 
langauges.remove("javascript")
print(langauges)

langauges[0] = "C"
print(langauges)

lang1 = ["lagchain"]
lang2 = ["LAGGRAPH"]
lang1.extend(lang2)

print(lang1)

print("golang" in langauges)

print(len(langauges))
# Out:
# ['java', 'javascript', 'python', 'golang']
# javascript
# ['python', 'golang']
# golang
# python
# ['golang', 'python', 'javascript', 'java']
# ['golang', 'javascript']
# ['javascript', 'python', 'golang']
# ['python', 'golang']
# ['C', 'golang']
# ['lagchain', 'LAGGRAPH']
# True
# 2

# %%
# dist

capitals = {"gujarat":"gandhinagar","nepal":"kathmandu"}
print(capitals)

capitals["italy"] ="rome"
print(capitals)





print(capitals["gujarat"])

del capitals["italy"]
print(capitals)
# Out:
# {'gujarat': 'gandhinagar', 'nepal': 'kathmandu'}
# {'gujarat': 'gandhinagar', 'nepal': 'kathmandu', 'italy': 'rome'}
# gandhinagar
# {'gujarat': 'gandhinagar', 'nepal': 'kathmandu'}

# %%
mapping = {1:2,3:4}
print(mapping)
del mapping
# print(mapping)
# Out:
# {1: 2, 3: 4}
